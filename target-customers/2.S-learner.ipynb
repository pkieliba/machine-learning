# %%
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif
from sklearn.compose import ColumnTransformer
from sklearn.metrics import confusion_matrix
from sklearn.metrics import fbeta_score, make_scorer
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline, make_pipeline
from xgboost import XGBClassifier
import lightgbm as lgb
import joblib
import logging
import optuna
from causalml.metrics.visualize import get_cumgain
from causalml.metrics import auuc_score


# %load_ext autoreload
# %aimport plotMethods
# %autoreload 1

np.random.seed(42)

# %% [markdown]
# # Uplift modeling - which customers to target?
#
# Modern world is full of advertisements and those are becoming more and more targeted. To win our attention, companies adapt to e.g. our digital viewing habits, collect our demographic data and then use this information to sell us things they think we may like. By focusing on specific traits, interests and preferences of a customer, targeted marketing is trying to **maximize the incremental impact of the promoted product**.
#
# But how do these marketing campaigns identify the right individuals to send discount coupons or personalized advertisements to? Certainly, running those campaigns incurs financial costs, and it is unfeasible to send discount coupons to everyone in the world. The cost of printing the coupons and the lost of potential revenues, resulting from the offered discount, might just outweigh the additional profits generated from new customers. In addition, what if the customer was already planning to buy the advertised coupon, without receiving any extra discounts or adverts? In that case, the retailer would generate less profit, as the customer will be paying less than what they already intended to pay. So how do you identify individuals who are **only likely to purchase** your product **if targeted by the marketing campaign**?
#
# ## Dataset
#
# Here, we will be using data provided by *Udacity* as part of their *Data Scientist Nanodegree*. This dataset was originally used as a take-home assignment given out by Starbucks during job application process. The data consists of about 120,000 data points split in a 2:1 ratio between training and testing sets. In the experiment, simulated by the data, Starbucks is about to launch a new marketing campaign based on sending promotional materials to selected customers. The team has run a randomized pilot (A/B testing) to test this campaign. In the pilot, a subset of customers was divided into two groups, only one of which received the promotion. The team recorded each customer's buying decision along with 7 features (*V1-V7*) encoding their personal characteristics. Based on the gathered data, we now want to know which other customers should be assigned to this campaign, in a way that would maximize generated profit. Since it costs the company *0.15* to contact each person, it would be best to limit the campaign only to the most receptive customers. As such, rather than predicting which customers would buy the product, we want to predict which customers would buy the product **only if contacted** (interaction).
#
# ## Goal
#
# Our goal is to maximize the **profit of the campaign**:
#
# $profit = \sum \limits _{i=1} ^{N} 10*purchase_{i}(decision_{i}) - 0.15*decision_{i}$,
#
# where *purchase* is a purchasing decision of an individual client influenced by the *decision* - a binary indicator of whether that person has been targeted or not.
#
# To account for the fact that some customers buy the product even if not targeted, we should also look at the **net incremental profit**, defined as:
#
# $NIR = profit-10*nControlPurchase$,
#
# where *nControlPurchase* is the number of people, who were not targeted and bought the service.
#
# Furthermore, Starbucks asked their job candidates to also optimize the **incremental response rate**, defined as:
#
# $IRR = \frac{nTreatPurchase}{nTreat} - \frac{nControlPurchase}{nControl}$,
#
# where *nTreatPurchase* is the number of people, who were not targeted and bought the service; and *nTreat* and *nControl* are the number of targeted and non-targeted customers respectively.
#
# For this assignment, Starbucks claimed to have a model that achieved a NIR of 189.45 and an IRR of 1.88%. Note that this assignment is quite outdated though and it is very likely that Starbucks will have a better model now! Yet, these numbers will serve us as the benchmarks to beat.
#
# ## The approach
#
# The problem of deciding whether it is profitable to target a particular customer can be tackled from two different perspectives:
#
# 1. traditional predictive modeling, where the problem is treated as a common classification task
# 2. uplift modeling, where the incremental probability of purchase is modeled
#
# Here, we're gonna compare both of those perspectives and use a total of four different approaches to choosing which customers to target:
#
# 1. [Traditional predictive model](./1.Classical-predictive-models.ipynb)
# 2. S-learner model (one-model "uplift classifier")
# 3. [T-learner model (two-models "uplift classifier")](./3.T-learner.ipynb)
# 4. [Direct uplift modeling](./4.Direct-uplift)
#
# # S-learner (one-model uplift classifier)
#
# In order to model the impact of treatment (receiving a promotion) with a single model, we will train our model using the treatment (promotion yes/no) variable as one of our features. We will then use this information to train the model to predict the probability of an individual buying the product. To make predictions for the new observations, and to decide whom to target, we will force the treatment variable to 0 (not targeted) and get a prediction on how likely each person is to buy our product if not targeted. We will then force the treatment variable to 1 (targeted) and get a second prediction on how likely each person is to buy the product if targeted. The difference in those two probabilities will give us our uplift score. Here, we would only want to target the customers who are significantly more likely to buy the product if targeted, as compared to when not targeted.

# %%
data = pd.read_csv("data/training.csv")
data['Promotion'] = data['Promotion'].replace({'No': 0, 'Yes': 1})

# %% [markdown]
# ## Exploratory Data Analysis
#
# First, we need to learn a little bit more about our data - what type of variables are we working with, how many data points do we have, do we have to deal with any missing data etc.

# %%
plotMethods.eda(data)
# Out:
#               type  count  missing  unique          mean           std  \
# ID           int64  84534        0   84534  62970.972413  36418.440539
# Promotion    int64  84534        0       2      0.501147      0.500002
# purchase     int64  84534        0       2      0.012303      0.110234
# V1           int64  84534        0       4      1.500662      0.868234
# V2         float64  84534        0   84518     29.973600      5.010626
# V3         float64  84534        0      40      0.000190      1.000485
# V4           int64  84534        0       2      1.679608      0.466630
# V5           int64  84534        0       4      2.327643      0.841167
# V6           int64  84534        0       4      2.502898      1.117349
# V7           int64  84534        0       2      1.701694      0.457517
#
#                 min            max   kurtosis      skew
# ID         1.000000  126184.000000  -1.199707  0.005485
# Promotion  0.000000       1.000000  -2.000026 -0.004590
# purchase   0.000000       1.000000  76.299732  8.848612
# V1         0.000000       3.000000  -0.673422  0.000404
# V2         7.104007      50.375913   0.021425 -0.011369
# V3        -1.684550       1.691984  -1.205420  0.004073
# V4         1.000000       2.000000  -1.407398 -0.769828
# V5         1.000000       4.000000  -0.743953 -0.059024
# V6         1.000000       4.000000  -1.358416 -0.003446
# V7         1.000000       2.000000  -1.222616 -0.881710

# %% [markdown]
# We have 11 variables - 7 Vs corresponding to customers' features, an information on whether the customer has been targeted in the A/B test (Promotion), customer's purchase decision (purchase), customer's ID and finally the (added) target variable indicating whether the customer should be target in the new marketing campaign. The customer ID should be a random value assigned to the customer for identification purposes, it won't be helpful to us here. We have **no categorical features** and **no missing data**, we do have a couple of **binary variables** and 3 further **integer variables**, that may potentially be ordinal. The features are. not labeled purposefully, as Strabucks wanted the job candidate to focus solely on the analytical process without being able to benefit from business insights.
#
# But before we take a closer look at all that, let's check our **Promotion** and **purchase** columns. What is the outcome of our A/B testing? Is our marketing campaign working?

# %%
data.columns = ['ID', 'promotion', 'purchase', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7']

chi, p, _, _ = stats.chi2_contingency(pd.crosstab(data['purchase'], data['promotion']))
print("\n Chi square test of independence - chi2: {}, p-value: {} \n".format(chi, p))
origProfit = pd.crosstab(data['purchase'], data['promotion'], margins=True, margins_name="total")
origProfit
# Out:
#  Chi square test of independence - chi2: 154.6851420820884, p-value: 1.6405910232768956e-35
# promotion      0      1  total
# purchase
# 0          41851  41643  83494
# 1            319    721   1040
# total      42170  42364  84534

# %% [markdown]
# All right, so from our group of 84534 customers, approximately 50% (42364) were targeted during the A/B testing. Out of those about 2% (721) purchased the product. Additional 319 purchases were made by non-targeted customers (~1% of all non-targeted customers). Statistical testing *(chi square test of independence)* reveals that there is a **significant relationship between the purchase and treatment variables**, suggesting that the new campaign is indeed working.
#
# What is important to note is that we are working with a **highly imbalanced dataset**. This is going to affect the metric we choose for model evaluation. We may also want to upsample/downsample our data.
#
# Let's have a look at what profit generated by this campaign.

# %%
profit = 10*1040 - 0.15*42364
NIR = profit - 10*319
IRR = 721/42364 - 319/41851
print("profit: {:.2f}, NIR: {:.2f}, IRR: {:.2f}%".format(profit, NIR, IRR*100))
# Out:
# profit: 4045.40, NIR: 855.40, IRR: 0.94%

# %% [markdown]
# The campaign generated a NIR of 855.4 and IRR of 1%. Can we do better?
#
# Let's also have a closer look at the distributions of our variables.

# %%
f, axes = plt.subplots(2, 4, figsize=(20,10), sharex=False)
sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 2.5})
plt.style.use("seaborn-white")
for ax, feature in zip(axes.flat, list(data.iloc[:,3:].select_dtypes(exclude='object').columns) + ['promotion']):
    sns.distplot(data[feature], kde_kws = {"color": "deepskyblue"}, 
                 hist_kws = {"color": "skyblue"}, ax=ax)
    sns.despine()
    ax.set(title=feature)
    ax.set(xlabel=None)
plt.tight_layout()
# Out:
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
fig, ax = plt.subplots(figsize=(10,7))
mask = np.triu(data.iloc[:,1:].corr()) # mask to display only lower triangle of the heatmap
sns.heatmap(data.iloc[:,1:].corr(method='spearman'), annot=True, mask=mask, ax=ax, fmt=".2f", cmap="RdBu_r")

# %% [markdown]
# From the heatmap, we can see there is very little colinearity between the features themselves.

# %%
g = sns.pairplot(data, vars=list(data.iloc[:,3:].select_dtypes(exclude='object').columns) + ['promotion'], 
                 hue="purchase", corner=True, height=1.5, palette = {0: 'darkgray', 1: 'darkorange'})

# %%
crossV1 = pd.DataFrame(pd.crosstab(data['V1'], data['purchase'], normalize="index")*100)
crossV1target = pd.DataFrame(pd.crosstab(data['V1'],data['purchase'], normalize="columns")*100).transpose()
display(pd.crosstab(data['V1'],data['purchase']).transpose())

fig, ax = plt.subplots(1, 3, figsize=(14,4))
# countplot
g1 = sns.countplot(x="V1", hue="purchase", data=data, palette = {0: 'lightgray', 1: 'darkorange'}, 
                   saturation=1,linewidth=1, edgecolor="black", ax=ax[0])
sns.despine()
# percentage in each category
g2 = crossV1.plot(kind="bar", stacked=True, color=["lightgray", "darkorange"], edgecolor='black', ax=ax[1])
g2.spines['right'].set_visible(False)
g2.spines['top'].set_visible(False)
g2.set_xticklabels(g2.get_xticklabels(),rotation=0)
g2.set_ylabel("percentage")
g2.get_legend().remove()
# percentage of purchase
g3 = crossV1target.plot(kind="bar", stacked=True, cmap="tab20", edgecolor='black', ax=ax[2])
g3.spines['right'].set_visible(False)
g3.spines['top'].set_visible(False)
g3.set_xticklabels(g3.get_xticklabels(),rotation=0)
g3.set_ylabel("percentage")
g3.legend_.set_bbox_to_anchor((1, 1))
# Out:
# V1            0      1      2      3
# purchase
# 0         10487  31241  31203  10563
# 1           138    390    405    107

# %%
crossV4 = pd.DataFrame(pd.crosstab(data['V4'], data['purchase'], normalize="index")*100)
crossV4target = pd.DataFrame(pd.crosstab(data['V4'],data['purchase'], normalize="columns")*100).transpose()
display(pd.crosstab(data['V4'],data['purchase']).transpose())

fig, ax = plt.subplots(1, 3, figsize=(14,4))
# countplot
g1 = sns.countplot(x="V4", hue="purchase", data=data, palette = {0: 'lightgray', 1: 'darkorange'}, 
                   saturation=1,linewidth=1, edgecolor="black", ax=ax[0])
sns.despine()
# percentage in each category
g2 = crossV4.plot(kind="bar", stacked=True, color=["lightgray", "darkorange"], edgecolor='black', ax=ax[1])
g2.spines['right'].set_visible(False)
g2.spines['top'].set_visible(False)
g2.set_xticklabels(g2.get_xticklabels(),rotation=0)
g2.set_ylabel("percentage")
g2.get_legend().remove()
# percentage of purchase
g3 = crossV4target.plot(kind="bar", stacked=True, cmap="tab20", edgecolor='black', ax=ax[2])
g3.spines['right'].set_visible(False)
g3.spines['top'].set_visible(False)
g3.set_xticklabels(g3.get_xticklabels(),rotation=0)
g3.set_ylabel("percentage")
g3.legend_.set_bbox_to_anchor((1, 1))
# Out:
# V4            1      2
# purchase
# 0         26891  56603
# 1           193    847

# %%
crossV5 = pd.DataFrame(pd.crosstab(data['V5'], data['purchase'], normalize="index")*100)
crossV5target = pd.DataFrame(pd.crosstab(data['V5'],data['purchase'], normalize="columns")*100).transpose()
display(pd.crosstab(data['V5'],data['purchase']).transpose())

fig, ax = plt.subplots(1, 3, figsize=(14,4))
# countplot
g1 = sns.countplot(x="V5", hue="purchase", data=data, palette = {0: 'lightgray', 1: 'darkorange'}, 
                   saturation=1,linewidth=1, edgecolor="black", ax=ax[0])
sns.despine()
# percentage in each category
g2 = crossV5.plot(kind="bar", stacked=True, color=["lightgray", "darkorange"], edgecolor='black', ax=ax[1])
g2.spines['right'].set_visible(False)
g2.spines['top'].set_visible(False)
g2.set_xticklabels(g2.get_xticklabels(),rotation=0)
g2.set_ylabel("percentage")
g2.get_legend().remove()
# percentage of purchase
g3 = crossV5target.plot(kind="bar", stacked=True, cmap="tab20", edgecolor='black', ax=ax[2])
g3.spines['right'].set_visible(False)
g3.spines['top'].set_visible(False)
g3.set_xticklabels(g3.get_xticklabels(),rotation=0)
g3.set_ylabel("percentage")
g3.legend_.set_bbox_to_anchor((1, 1))
# Out:
# V5            1      2      3     4
# purchase
# 0         15201  30915  32260  5118
# 1           211    281    483    65

# %%
crossV6 = pd.DataFrame(pd.crosstab(data['V6'], data['purchase'], normalize="index")*100)
crossV6target = pd.DataFrame(pd.crosstab(data['V6'],data['purchase'], normalize="columns")*100).transpose()
display(pd.crosstab(data['V6'],data['purchase']).transpose())

fig, ax = plt.subplots(1, 3, figsize=(14,4))
# countplot
g1 = sns.countplot(x="V6", hue="purchase", data=data, palette = {0: 'lightgray', 1: 'darkorange'}, 
                   saturation=1,linewidth=1, edgecolor="black", ax=ax[0])
g1.legend_.set_bbox_to_anchor((0.8, 1))
sns.despine()
# percentage in each category
g2 = crossV6.plot(kind="bar", stacked=True, color=["lightgray", "darkorange"], edgecolor='black', ax=ax[1])
g2.spines['right'].set_visible(False)
g2.spines['top'].set_visible(False)
g2.set_xticklabels(g2.get_xticklabels(),rotation=0)
g2.set_ylabel("percentage")
g2.get_legend().remove()
# percentage of purchase
g3 = crossV6target.plot(kind="bar", stacked=True, cmap="tab20", edgecolor='black', ax=ax[2])
g3.spines['right'].set_visible(False)
g3.spines['top'].set_visible(False)
g3.set_xticklabels(g3.get_xticklabels(),rotation=0)
g3.set_ylabel("percentage")
g3.legend_.set_bbox_to_anchor((1, 1))
# Out:
# V6            1      2      3      4
# purchase
# 0         20764  20887  20917  20926
# 1           262    259    269    250

# %%
crossV7 = pd.DataFrame(pd.crosstab(data['V7'], data['purchase'], normalize="index")*100)
crossV7target = pd.DataFrame(pd.crosstab(data['V7'],data['purchase'], normalize="columns")*100).transpose()
display(pd.crosstab(data['V7'],data['purchase']).transpose())

fig, ax = plt.subplots(1, 3, figsize=(14,4))
# countplot
g1 = sns.countplot(x="V7", hue="purchase", data=data, palette = {0: 'lightgray', 1: 'darkorange'}, 
                   saturation=1,linewidth=1, edgecolor="black", ax=ax[0])
sns.despine()
# percentage in each category
g2 = crossV7.plot(kind="bar", stacked=True, color=["lightgray", "darkorange"], edgecolor='black', ax=ax[1])
g2.spines['right'].set_visible(False)
g2.spines['top'].set_visible(False)
g2.set_xticklabels(g2.get_xticklabels(),rotation=0)
g2.set_ylabel("percentage")
g2.get_legend().remove()
# percentage of purchase
g3 = crossV7target.plot(kind="bar", stacked=True, cmap="tab20", edgecolor='black', ax=ax[2])
g3.spines['right'].set_visible(False)
g3.spines['top'].set_visible(False)
g3.set_xticklabels(g3.get_xticklabels(),rotation=0)
g3.set_ylabel("percentage")
g3.legend_.set_bbox_to_anchor((1, 1))
# Out:
# V7            1      2
# purchase
# 0         24902  58592
# 1           315    725

# %% [markdown]
# ## Modeling
#
# We will use the *purchase* column as the target that we want to predict. To quantify the performance of our models, we are going to split our dataset into training and dev subsets and use cross-validation to tune some of the models' parameters. The models that we are going to try are:
#
# 1. XGBoost model (boosting)
# 2. Random Forest model (bagging)

# %%
features = list(data.iloc[:,3:].select_dtypes(exclude='object').columns) + ['promotion']
X = data[features]
y = data.purchase
Xtrain, Xtest, Ytrain, Ytest, Ttrain, Ttest = train_test_split(X, y, data.promotion, test_size=0.1, stratify=y, random_state=42)

# %% [markdown]
# To reduce the computational load a bit, I am going to downsample the training set before tuning the hyperparameters. After choosing the hyperparameters, the model will be retrained on all the training data, but to make my computer's life a little bit easier, I am going to tune the hyperparameters based on 20000 observations. I will only be removing the observations coming from people that did not purchase the product.

# %%
NoPurch = data.query('purchase == 0').index
commonIdx = list(set(NoPurch).intersection(Xtrain.index))
toDrop = np.random.choice(commonIdx, 56080, replace=False)
Xhyper = Xtrain.drop(toDrop)
Yhyper = Ytrain.drop(toDrop)

# %%
plotMethods.eda(Xhyper)
# Out:
#               type  count  missing  unique       mean       std       min  \
# V1           int64  20000        0       4   1.501800  0.867199  0.000000
# V2         float64  20000        0   19999  29.935364  5.004820  8.939305
# V3         float64  20000        0      40  -0.000240  0.998665 -1.684550
# V4           int64  20000        0       2   1.680050  0.466469  1.000000
# V5           int64  20000        0       4   2.333000  0.848615  1.000000
# V6           int64  20000        0       4   2.510450  1.114519  1.000000
# V7           int64  20000        0       2   1.700650  0.457985  1.000000
# promotion    int64  20000        0       2   0.506200  0.499974  0.000000
#
#                  max  kurtosis      skew
# V1          3.000000 -0.670078 -0.001857
# V2         48.615385  0.059210 -0.009445
# V3          1.691984 -1.200688 -0.007022
# V4          2.000000 -1.404083 -0.772048
# V5          4.000000 -0.770349 -0.073673
# V6          4.000000 -1.351707 -0.014541
# V7          2.000000 -1.232191 -0.876318
# promotion   1.000000 -1.999585 -0.024804

# %%
bestFeatures = SelectKBest(mutual_info_classif, k='all')
bestFeatures.fit(Xtrain, Ytrain)
bestFeatures.scores_
# Out:
# array([0.00530275, 0.00060949, 0.00118218, 0.01115713, 0.00587156,
#        0.00436519, 0.01114072, 0.00580228])

# %% [markdown]
# Because our dataset is still **unbalanced**, instead of downsampling even more, we are going to use oversampling technique called **SMOTE**. SMOTE synthetically generates new data points belonging to the minority class (here, the customers that we should target).

# %%
numPipe = StandardScaler()
preproc = ColumnTransformer(transformers=[('num', numPipe, Xtrain.select_dtypes(include="number").columns)])

oversamp = SMOTE()

# %% [markdown]
# ### 1. XGBoost model (boosting)

# %%
model = XGBClassifier()
xgbPipe = make_pipeline(preproc, oversamp, model)

# %%
def objective(trial):
    
    xgbParams = {
        "xgbclassifier__n_estimators": 800, 
        "xgbclassifier__gamma": trial.suggest_float("xgbclassifier__gamma", 0, 0.4), 
        "xgbclassifier__alpha": trial.suggest_loguniform("xgbclassifier__alpha", 1e-3, 1e-1),
        "xgbclassifier__max_depth": trial.suggest_int("xgbclassifier__max_depth", 5, 10),
        "xgbclassifier__min_child_weight": trial.suggest_int("xgbclassifier__min_child_weight", 10, 60, 10), 
        "xgbclassifier__eta": trial.suggest_loguniform("xgbclassifier__eta", 1e-3, 1e-1)
    }
    xgbPipe.set_params(**xgbParams)
    
    scores = cross_val_score(xgbPipe, Xhyper, Yhyper, scoring='neg_log_loss', cv=5)
    
    return np.mean(scores)

# %%
xgbStudy = optuna.create_study(direction='maximize')
xgbStudy.optimize(objective, n_trials=100)

joblib.dump(xgbStudy, './models/xgb-slearn')  # save model
# Out:
# [I 2020-11-13 21:32:45,600] A new study created in memory with name: no-name-7153e531-515e-47dd-b541-5d8d3bfc8caf
# [I 2020-11-13 21:33:21,855] Trial 0 finished with value: -0.5566435201004147 and parameters: {'xgbclassifier__gamma': 0.2535991941317594, 'xgbclassifier__alpha': 0.03193404728603085, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 30, 'xgbclassifier__eta': 0.001527819319787586}. Best is trial 0 with value: -0.5566435201004147.
# [I 2020-11-13 21:34:06,889] Trial 1 finished with value: -0.20175804552994014 and parameters: {'xgbclassifier__gamma': 0.36356624026504664, 'xgbclassifier__alpha': 0.03306457336419109, 'xgbclassifier__max_depth': 7, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.08421211383586165}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:34:59,322] Trial 2 finished with value: -0.5291190188266336 and parameters: {'xgbclassifier__gamma': 0.06717529633823519, 'xgbclassifier__alpha': 0.05467312290461731, 'xgbclassifier__max_depth': 7, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.0013113924921876303}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:35:34,221] Trial 3 finished with value: -0.4908006877426058 and parameters: {'xgbclassifier__gamma': 0.108813146448734, 'xgbclassifier__alpha': 0.011610464092346838, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 60, 'xgbclassifier__eta': 0.002806992672852369}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:36:06,454] Trial 4 finished with value: -0.23014867138019762 and parameters: {'xgbclassifier__gamma': 0.39085803175061407, 'xgbclassifier__alpha': 0.004909873071255775, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 60, 'xgbclassifier__eta': 0.05730951658801698}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:36:41,163] Trial 5 finished with value: -0.34501173294594045 and parameters: {'xgbclassifier__gamma': 0.286267426178721, 'xgbclassifier__alpha': 0.01064902688104161, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 30, 'xgbclassifier__eta': 0.010579022242897921}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:37:20,383] Trial 6 finished with value: -0.24950042446448933 and parameters: {'xgbclassifier__gamma': 0.2610622031899161, 'xgbclassifier__alpha': 0.002293704082512264, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 30, 'xgbclassifier__eta': 0.020009423263880846}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:37:54,361] Trial 7 finished with value: -0.3542137878295034 and parameters: {'xgbclassifier__gamma': 0.09246657803705488, 'xgbclassifier__alpha': 0.07769793485542893, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 30, 'xgbclassifier__eta': 0.009663039277252537}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:38:56,944] Trial 8 finished with value: -0.20645129645602428 and parameters: {'xgbclassifier__gamma': 0.13371696268217428, 'xgbclassifier__alpha': 0.04294069150283694, 'xgbclassifier__max_depth': 10, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.023716255242077385}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:39:47,097] Trial 9 finished with value: -0.46487069582231344 and parameters: {'xgbclassifier__gamma': 0.3650251875586019, 'xgbclassifier__alpha': 0.0036236615105170946, 'xgbclassifier__max_depth': 7, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.0023112690509401205}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:40:36,039] Trial 10 finished with value: -0.2048759516851511 and parameters: {'xgbclassifier__gamma': 0.3338377072878377, 'xgbclassifier__alpha': 0.021099974366654728, 'xgbclassifier__max_depth': 9, 'xgbclassifier__min_child_weight': 50, 'xgbclassifier__eta': 0.09735247649792597}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:41:25,914] Trial 11 finished with value: -0.20479434633046037 and parameters: {'xgbclassifier__gamma': 0.3378332136716188, 'xgbclassifier__alpha': 0.01999175293137649, 'xgbclassifier__max_depth': 9, 'xgbclassifier__min_child_weight': 50, 'xgbclassifier__eta': 0.08872657046503168}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:42:16,325] Trial 12 finished with value: -0.20570143924294976 and parameters: {'xgbclassifier__gamma': 0.39331168239152237, 'xgbclassifier__alpha': 0.017756047508665877, 'xgbclassifier__max_depth': 9, 'xgbclassifier__min_child_weight': 50, 'xgbclassifier__eta': 0.08040939032948442}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:43:03,416] Trial 13 finished with value: -0.21497352241351037 and parameters: {'xgbclassifier__gamma': 0.0006637674649057623, 'xgbclassifier__alpha': 0.02489988903198177, 'xgbclassifier__max_depth': 8, 'xgbclassifier__min_child_weight': 50, 'xgbclassifier__eta': 0.048799776893228675}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:43:51,672] Trial 14 finished with value: -0.21770693616695933 and parameters: {'xgbclassifier__gamma': 0.191207243915179, 'xgbclassifier__alpha': 0.008133243052857377, 'xgbclassifier__max_depth': 8, 'xgbclassifier__min_child_weight': 40, 'xgbclassifier__eta': 0.03620554190526033}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:44:45,434] Trial 15 finished with value: -0.2040279014105996 and parameters: {'xgbclassifier__gamma': 0.3181381161362313, 'xgbclassifier__alpha': 0.08946122767715087, 'xgbclassifier__max_depth': 10, 'xgbclassifier__min_child_weight': 40, 'xgbclassifier__eta': 0.08807569847107992}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:45:26,877] Trial 16 finished with value: -0.3595027282589581 and parameters: {'xgbclassifier__gamma': 0.2981848350192482, 'xgbclassifier__alpha': 0.0979861156004117, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.0070336214926545616}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:46:24,615] Trial 17 finished with value: -0.22889801331147322 and parameters: {'xgbclassifier__gamma': 0.1888152871866179, 'xgbclassifier__alpha': 0.06897264404397682, 'xgbclassifier__max_depth': 10, 'xgbclassifier__min_child_weight': 40, 'xgbclassifier__eta': 0.024911927237019713}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:47:08,772] Trial 18 finished with value: -0.20334372192583397 and parameters: {'xgbclassifier__gamma': 0.39897284545083206, 'xgbclassifier__alpha': 0.04250168002409533, 'xgbclassifier__max_depth': 7, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.055449739311857094}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:47:47,925] Trial 19 finished with value: -0.20694962352592264 and parameters: {'xgbclassifier__gamma': 0.3973698868802143, 'xgbclassifier__alpha': 0.04607819293704693, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.04292767315981585}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:48:36,399] Trial 20 finished with value: -0.3810932720554061 and parameters: {'xgbclassifier__gamma': 0.2389191319025692, 'xgbclassifier__alpha': 0.038656887095920224, 'xgbclassifier__max_depth': 7, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.005008855802866749}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:49:25,934] Trial 21 finished with value: -0.20308653097714996 and parameters: {'xgbclassifier__gamma': 0.34177997773301183, 'xgbclassifier__alpha': 0.09411287973466877, 'xgbclassifier__max_depth': 8, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.06497674935175948}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:50:15,521] Trial 22 finished with value: -0.20318958219194175 and parameters: {'xgbclassifier__gamma': 0.3582728065045063, 'xgbclassifier__alpha': 0.06354656265875276, 'xgbclassifier__max_depth': 8, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.06265792912974107}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:51:07,129] Trial 23 finished with value: -0.20269238110566806 and parameters: {'xgbclassifier__gamma': 0.36619529692234926, 'xgbclassifier__alpha': 0.06664070549965069, 'xgbclassifier__max_depth': 8, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.0326836564279248}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:51:59,287] Trial 24 finished with value: -0.20311580185513595 and parameters: {'xgbclassifier__gamma': 0.34974508844163915, 'xgbclassifier__alpha': 0.09842482192107282, 'xgbclassifier__max_depth': 8, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.03287808171459102}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:52:57,790] Trial 25 finished with value: -0.2194611167926923 and parameters: {'xgbclassifier__gamma': 0.3063768170880343, 'xgbclassifier__alpha': 0.0010367128839516588, 'xgbclassifier__max_depth': 9, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.01596462570145641}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:53:49,419] Trial 26 finished with value: -0.2021403166590666 and parameters: {'xgbclassifier__gamma': 0.3741585955553866, 'xgbclassifier__alpha': 0.029879902177317744, 'xgbclassifier__max_depth': 8, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.03409723228500809}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:54:42,359] Trial 27 finished with value: -0.2278084539356525 and parameters: {'xgbclassifier__gamma': 0.3650985056846649, 'xgbclassifier__alpha': 0.028437387746569537, 'xgbclassifier__max_depth': 8, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.015438795226683325}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:55:28,971] Trial 28 finished with value: -0.20548972980925173 and parameters: {'xgbclassifier__gamma': 0.278336847009308, 'xgbclassifier__alpha': 0.01446786496696147, 'xgbclassifier__max_depth': 7, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.03183661523319206}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:56:09,130] Trial 29 finished with value: -0.2671686645007343 and parameters: {'xgbclassifier__gamma': 0.22803616652766467, 'xgbclassifier__alpha': 0.0303971102945867, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.014926812254818952}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:57:06,246] Trial 30 finished with value: -0.2042142312797747 and parameters: {'xgbclassifier__gamma': 0.37799569164487534, 'xgbclassifier__alpha': 0.03382450921944654, 'xgbclassifier__max_depth': 9, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.03071640092366222}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:57:55,161] Trial 31 finished with value: -0.2029326131345326 and parameters: {'xgbclassifier__gamma': 0.32828355270397896, 'xgbclassifier__alpha': 0.05730210124473229, 'xgbclassifier__max_depth': 8, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.07317120332635828}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:58:40,547] Trial 32 finished with value: -0.2029535726093367 and parameters: {'xgbclassifier__gamma': 0.31267753953195476, 'xgbclassifier__alpha': 0.05997779509037366, 'xgbclassifier__max_depth': 7, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.04501921140736859}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 21:59:30,776] Trial 33 finished with value: -0.20377569027606368 and parameters: {'xgbclassifier__gamma': 0.37665874373660113, 'xgbclassifier__alpha': 0.0516000840546358, 'xgbclassifier__max_depth': 8, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.07789203228252921}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 22:00:14,967] Trial 34 finished with value: -0.2065815414830344 and parameters: {'xgbclassifier__gamma': 0.3367945015343033, 'xgbclassifier__alpha': 0.057579653593221716, 'xgbclassifier__max_depth': 7, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.0417766658681848}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 22:01:05,699] Trial 35 finished with value: -0.20400538899642048 and parameters: {'xgbclassifier__gamma': 0.2661783956777025, 'xgbclassifier__alpha': 0.013927254684925932, 'xgbclassifier__max_depth': 8, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.07170306904846724}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 22:02:00,499] Trial 36 finished with value: -0.228209977554623 and parameters: {'xgbclassifier__gamma': 0.380288056662435, 'xgbclassifier__alpha': 0.023478164304007898, 'xgbclassifier__max_depth': 9, 'xgbclassifier__min_child_weight': 30, 'xgbclassifier__eta': 0.02255852773909303}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 22:02:45,040] Trial 37 finished with value: -0.20366674440285712 and parameters: {'xgbclassifier__gamma': 0.16019394173766852, 'xgbclassifier__alpha': 0.007618600473346334, 'xgbclassifier__max_depth': 7, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.04952089617862059}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 22:03:35,578] Trial 38 finished with value: -0.2056090717736064 and parameters: {'xgbclassifier__gamma': 0.3205247256193767, 'xgbclassifier__alpha': 0.03388122190308565, 'xgbclassifier__max_depth': 8, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.0947869511032939}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 22:04:19,876] Trial 39 finished with value: -0.2270517972385278 and parameters: {'xgbclassifier__gamma': 0.004128637387497941, 'xgbclassifier__alpha': 0.07249905383120596, 'xgbclassifier__max_depth': 7, 'xgbclassifier__min_child_weight': 30, 'xgbclassifier__eta': 0.027472371954513117}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 22:05:12,406] Trial 40 finished with value: -0.2164501099756977 and parameters: {'xgbclassifier__gamma': 0.28679457964441535, 'xgbclassifier__alpha': 0.04654259560366811, 'xgbclassifier__max_depth': 8, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.01848557036069053}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 22:05:58,424] Trial 41 finished with value: -0.20297101422288977 and parameters: {'xgbclassifier__gamma': 0.3165966259371004, 'xgbclassifier__alpha': 0.05728881859125256, 'xgbclassifier__max_depth': 7, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.04105999310815078}. Best is trial 1 with value: -0.20175804552994014.
# [I 2020-11-13 22:06:38,108] Trial 42 finished with value: -0.20062294092742378 and parameters: {'xgbclassifier__gamma': 0.35694206822028557, 'xgbclassifier__alpha': 0.07650584598203164, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.05693452267242748}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:07:17,656] Trial 43 finished with value: -0.20181783937385478 and parameters: {'xgbclassifier__gamma': 0.3621867655561645, 'xgbclassifier__alpha': 0.07221072316763122, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.05727442312928756}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:07:52,231] Trial 44 finished with value: -0.20164255850309565 and parameters: {'xgbclassifier__gamma': 0.3590724154179192, 'xgbclassifier__alpha': 0.07571098365699362, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.06228216465286721}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:08:25,814] Trial 45 finished with value: -0.2008036222947645 and parameters: {'xgbclassifier__gamma': 0.35361336549809197, 'xgbclassifier__alpha': 0.08413514708362481, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.09962514137534971}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:09:02,834] Trial 46 finished with value: -0.5863397833041846 and parameters: {'xgbclassifier__gamma': 0.3975475307450546, 'xgbclassifier__alpha': 0.08105338999877447, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 30, 'xgbclassifier__eta': 0.0010517284802655715}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:09:36,499] Trial 47 finished with value: -0.20082998258408336 and parameters: {'xgbclassifier__gamma': 0.3525574885812015, 'xgbclassifier__alpha': 0.08033326131178824, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.09669501819279706}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:10:09,972] Trial 48 finished with value: -0.20272968017308157 and parameters: {'xgbclassifier__gamma': 0.34523059086668373, 'xgbclassifier__alpha': 0.08635207952149072, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 30, 'xgbclassifier__eta': 0.09399401830098607}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:10:44,023] Trial 49 finished with value: -0.20127060205777525 and parameters: {'xgbclassifier__gamma': 0.2914023133007444, 'xgbclassifier__alpha': 0.09962543775126795, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.09673034336459421}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:11:17,786] Trial 50 finished with value: -0.20366601932210324 and parameters: {'xgbclassifier__gamma': 0.2960382320969014, 'xgbclassifier__alpha': 0.09746667557810301, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 30, 'xgbclassifier__eta': 0.09217011871276329}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:11:51,563] Trial 51 finished with value: -0.20273250400697 and parameters: {'xgbclassifier__gamma': 0.35348921798312677, 'xgbclassifier__alpha': 0.08059333801324255, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.07196488078595945}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:12:30,740] Trial 52 finished with value: -0.20192956715845503 and parameters: {'xgbclassifier__gamma': 0.38666346998374856, 'xgbclassifier__alpha': 0.09909779685131498, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.09891208715388884}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:13:04,023] Trial 53 finished with value: -0.20753002083416217 and parameters: {'xgbclassifier__gamma': 0.2441924001549823, 'xgbclassifier__alpha': 0.03843725241509425, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.05494254800450872}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:13:42,941] Trial 54 finished with value: -0.2019954661147727 and parameters: {'xgbclassifier__gamma': 0.3297766306264699, 'xgbclassifier__alpha': 0.048675167448343264, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.06387461570592337}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:14:15,965] Trial 55 finished with value: -0.20404990439011014 and parameters: {'xgbclassifier__gamma': 0.3458145754002057, 'xgbclassifier__alpha': 0.0778957892513912, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 30, 'xgbclassifier__eta': 0.08212530000978611}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:14:59,177] Trial 56 finished with value: -0.48529325825981795 and parameters: {'xgbclassifier__gamma': 0.2704013896675946, 'xgbclassifier__alpha': 0.0036436380857687726, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.002312720404979831}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:15:32,401] Trial 57 finished with value: -0.2007753270960413 and parameters: {'xgbclassifier__gamma': 0.2217429195688219, 'xgbclassifier__alpha': 0.06702144695455314, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.09868534935484503}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:16:06,315] Trial 58 finished with value: -0.20131499809726955 and parameters: {'xgbclassifier__gamma': 0.21663517163195598, 'xgbclassifier__alpha': 0.06940506815514874, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.08108407663136631}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:16:39,410] Trial 59 finished with value: -0.20284563183999854 and parameters: {'xgbclassifier__gamma': 0.2035687545758049, 'xgbclassifier__alpha': 0.06392516158243468, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 30, 'xgbclassifier__eta': 0.09652732364697834}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:17:12,753] Trial 60 finished with value: -0.20191470648899848 and parameters: {'xgbclassifier__gamma': 0.22293435930577646, 'xgbclassifier__alpha': 0.09877880780917397, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.0796862246012916}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:17:46,353] Trial 61 finished with value: -0.2012209202985949 and parameters: {'xgbclassifier__gamma': 0.2539017033123708, 'xgbclassifier__alpha': 0.0870200356589497, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.0995844126299747}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:18:19,604] Trial 62 finished with value: -0.20196236283813485 and parameters: {'xgbclassifier__gamma': 0.20992645582310376, 'xgbclassifier__alpha': 0.086302752561944, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.0976983504322738}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:18:52,928] Trial 63 finished with value: -0.20102678200618246 and parameters: {'xgbclassifier__gamma': 0.1806141359888786, 'xgbclassifier__alpha': 0.06675426002124438, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.08072273539085051}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:19:34,057] Trial 64 finished with value: -0.4150791217966005 and parameters: {'xgbclassifier__gamma': 0.16806218857812255, 'xgbclassifier__alpha': 0.039875753519748515, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.0045269760130389755}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:20:07,198] Trial 65 finished with value: -0.2027470758536103 and parameters: {'xgbclassifier__gamma': 0.16148146857573967, 'xgbclassifier__alpha': 0.05051328386429816, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.07047874775602517}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:20:40,748] Trial 66 finished with value: -0.20147639317613214 and parameters: {'xgbclassifier__gamma': 0.18966498356173672, 'xgbclassifier__alpha': 0.08758421395244635, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.09937052654989545}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:21:19,185] Trial 67 finished with value: -0.21152709013940768 and parameters: {'xgbclassifier__gamma': 0.13099474133429284, 'xgbclassifier__alpha': 0.0975633781087945, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 40, 'xgbclassifier__eta': 0.056556532912231235}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:21:51,770] Trial 68 finished with value: -0.20453483976489517 and parameters: {'xgbclassifier__gamma': 0.24665458654108072, 'xgbclassifier__alpha': 0.06452963985137196, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 30, 'xgbclassifier__eta': 0.08330982256303177}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:22:30,565] Trial 69 finished with value: -0.20366391045186322 and parameters: {'xgbclassifier__gamma': 0.25444333306114925, 'xgbclassifier__alpha': 0.0016583236006212068, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.052191613765640806}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:23:03,726] Trial 70 finished with value: -0.20312382169121412 and parameters: {'xgbclassifier__gamma': 0.22758846383479606, 'xgbclassifier__alpha': 0.05103368426485699, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.06520907048195032}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:23:36,919] Trial 71 finished with value: -0.20155453045103933 and parameters: {'xgbclassifier__gamma': 0.2067025194017377, 'xgbclassifier__alpha': 0.07112621599684647, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.08676279369011967}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:24:10,253] Trial 72 finished with value: -0.20230033287115803 and parameters: {'xgbclassifier__gamma': 0.1715051656789269, 'xgbclassifier__alpha': 0.0651366306116974, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.0786759484486474}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:24:43,598] Trial 73 finished with value: -0.2018322738304123 and parameters: {'xgbclassifier__gamma': 0.21999562645534015, 'xgbclassifier__alpha': 0.05516451912614271, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.09907728358259839}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:25:16,898] Trial 74 finished with value: -0.20309334992427033 and parameters: {'xgbclassifier__gamma': 0.17773256335795115, 'xgbclassifier__alpha': 0.08636644649401821, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.06899414070020077}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:25:50,697] Trial 75 finished with value: -0.2115047412147571 and parameters: {'xgbclassifier__gamma': 0.13979956563048576, 'xgbclassifier__alpha': 0.043151451028385926, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.04609882934712063}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:26:29,379] Trial 76 finished with value: -0.20315702903921773 and parameters: {'xgbclassifier__gamma': 0.2343324354196842, 'xgbclassifier__alpha': 0.09995584852992083, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 30, 'xgbclassifier__eta': 0.08687983526542677}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:27:03,362] Trial 77 finished with value: -0.32984602015644776 and parameters: {'xgbclassifier__gamma': 0.2799704563317399, 'xgbclassifier__alpha': 0.07500524861571935, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.012017947367362397}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:27:36,503] Trial 78 finished with value: -0.2023747966054769 and parameters: {'xgbclassifier__gamma': 0.30480501765847623, 'xgbclassifier__alpha': 0.0618492862471694, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 30, 'xgbclassifier__eta': 0.09998692711126776}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:28:10,471] Trial 79 finished with value: -0.2190803460660856 and parameters: {'xgbclassifier__gamma': 0.21427004132842883, 'xgbclassifier__alpha': 0.06965465325421308, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.03737957430861562}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:28:49,096] Trial 80 finished with value: -0.20132986331827413 and parameters: {'xgbclassifier__gamma': 0.25622327172615633, 'xgbclassifier__alpha': 0.08914148814270391, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.07601819585014}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:29:25,476] Trial 81 finished with value: -0.21375236246739515 and parameters: {'xgbclassifier__gamma': 0.2598250721885147, 'xgbclassifier__alpha': 0.08627442439312859, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 60, 'xgbclassifier__eta': 0.07488669962196166}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:29:58,569] Trial 82 finished with value: -0.20511872492530384 and parameters: {'xgbclassifier__gamma': 0.2506965688686326, 'xgbclassifier__alpha': 0.056404358803548285, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.05963590404171766}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:30:32,129] Trial 83 finished with value: -0.20143828251230297 and parameters: {'xgbclassifier__gamma': 0.2357281844776498, 'xgbclassifier__alpha': 0.07872586369523035, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.08722823989066707}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:31:10,628] Trial 84 finished with value: -0.2010999342184514 and parameters: {'xgbclassifier__gamma': 0.19817331848231276, 'xgbclassifier__alpha': 0.09976495625877978, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.07475488871855626}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:31:44,023] Trial 85 finished with value: -0.20280717611376314 and parameters: {'xgbclassifier__gamma': 0.15015500896310507, 'xgbclassifier__alpha': 0.07015190873408776, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 20, 'xgbclassifier__eta': 0.06623159741526263}. Best is trial 42 with value: -0.20062294092742378.
# [I 2020-11-13 22:32:17,568] Trial 86 finished with value: -0.20005690905661178 and parameters: {'xgbclassifier__gamma': 0.198295421207477, 'xgbclassifier__alpha': 0.04468461905683974, 'xgbclassifier__max_depth': 5, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.08451791660217951}. Best is trial 86 with value: -0.20005690905661178.
# [I 2020-11-13 22:32:57,370] Trial 87 finished with value: -0.2010978049906087 and parameters: {'xgbclassifier__gamma': 0.19405689907935705, 'xgbclassifier__alpha': 0.0980650200525014, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.04889816096706573}. Best is trial 86 with value: -0.20005690905661178.
# [I 2020-11-13 22:33:36,996] Trial 88 finished with value: -0.2014440770658373 and parameters: {'xgbclassifier__gamma': 0.19500687750344745, 'xgbclassifier__alpha': 0.03581206232147916, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.05026184954039027}. Best is trial 86 with value: -0.20005690905661178.
# [I 2020-11-13 22:34:16,386] Trial 89 finished with value: -0.200470880614224 and parameters: {'xgbclassifier__gamma': 0.1976099349501306, 'xgbclassifier__alpha': 0.04544400286897616, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.05838382092094899}. Best is trial 86 with value: -0.20005690905661178.
# [I 2020-11-13 22:34:55,968] Trial 90 finished with value: -0.2032099230891792 and parameters: {'xgbclassifier__gamma': 0.18405728651287398, 'xgbclassifier__alpha': 0.044873210457586084, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.041895833169141306}. Best is trial 86 with value: -0.20005690905661178.
# [I 2020-11-13 22:35:35,560] Trial 91 finished with value: -0.20022979520681697 and parameters: {'xgbclassifier__gamma': 0.19675462879011504, 'xgbclassifier__alpha': 0.0536991058407131, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.058976783449547085}. Best is trial 86 with value: -0.20005690905661178.
# [I 2020-11-13 22:36:14,787] Trial 92 finished with value: -0.20029523024918747 and parameters: {'xgbclassifier__gamma': 0.19830752710442362, 'xgbclassifier__alpha': 0.059676440408071525, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.060857970048079316}. Best is trial 86 with value: -0.20005690905661178.
# [I 2020-11-13 22:36:54,707] Trial 93 finished with value: -0.20349399023081644 and parameters: {'xgbclassifier__gamma': 0.17342752979798412, 'xgbclassifier__alpha': 0.05248564358620588, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.038257108929719424}. Best is trial 86 with value: -0.20005690905661178.
# [I 2020-11-13 22:37:34,061] Trial 94 finished with value: -0.20169583347881853 and parameters: {'xgbclassifier__gamma': 0.08956625027079201, 'xgbclassifier__alpha': 0.03895793816377638, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.0480366002360449}. Best is trial 86 with value: -0.20005690905661178.
# [I 2020-11-13 22:38:13,559] Trial 95 finished with value: -0.20086319313180864 and parameters: {'xgbclassifier__gamma': 0.18248131623192, 'xgbclassifier__alpha': 0.05909695031776764, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.05972582405231274}. Best is trial 86 with value: -0.20005690905661178.
# [I 2020-11-13 22:38:52,739] Trial 96 finished with value: -0.2007309270739963 and parameters: {'xgbclassifier__gamma': 0.18591276431427217, 'xgbclassifier__alpha': 0.024831656420937806, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.05665591051518443}. Best is trial 86 with value: -0.20005690905661178.
# [I 2020-11-13 22:39:31,901] Trial 97 finished with value: -0.20079456976968793 and parameters: {'xgbclassifier__gamma': 0.14962744389870825, 'xgbclassifier__alpha': 0.0270949456088014, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.05808676453272086}. Best is trial 86 with value: -0.20005690905661178.
# [I 2020-11-13 22:40:16,790] Trial 98 finished with value: -0.20166928595448116 and parameters: {'xgbclassifier__gamma': 0.12171382899028656, 'xgbclassifier__alpha': 0.0265706761762237, 'xgbclassifier__max_depth': 7, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.0539684971795698}. Best is trial 86 with value: -0.20005690905661178.
# [I 2020-11-13 22:40:56,185] Trial 99 finished with value: -0.2005367957774637 and parameters: {'xgbclassifier__gamma': 0.0376537870600116, 'xgbclassifier__alpha': 0.022300065717668127, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__eta': 0.060905908838479746}. Best is trial 86 with value: -0.20005690905661178.
# ['xgb-slearn']

# %%
xgbStudy = joblib.load('./models/xgb-slearn')
xgbStudy.best_params
# Out:
# {'xgbclassifier__alpha': 0.04468461905683974,
#  'xgbclassifier__eta': 0.08451791660217951,
#  'xgbclassifier__gamma': 0.198295421207477,
#  'xgbclassifier__max_depth': 5,
#  'xgbclassifier__min_child_weight': 10}

# %%
xgbPipe.set_params(**xgbStudy.best_params)
xgbPipe.fit(Xtrain,Ytrain)
joblib.dump(xgbPipe, './models/xgb-slearn-trained')
Ypred = xgbPipe.predict(Xtest)
Yprobs = xgbPipe.predict_proba(Xtest)[:,1]
cm = confusion_matrix(Ytest, Ypred)
# Out:
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [12:41:25] WARNING: /private/var/folders/5y/ckmm23d95n58xx4z7nxpw7nc0000gn/T/pip-install-6ps00z8a/xgboost_a61ff17cbf0a496a8d8024a6201289f8/build/temp.macosx-10.14-x86_64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
fig, axes = plt.subplots(3,3, figsize=(15,20), gridspec_kw={'hspace': 0.3})
axes[0,0].set_visible(False)
plotMethods.plotCM(cm, normalize=False, ax=axes[0,1], xlabel=False)
plotMethods.plotCM(cm, normalize=True, ax=axes[0,2], xlabel=False, ylabel=False)

_, bestROC = plotMethods.plotROC(Ytest, Yprobs, ax=axes[1,0])
plotMethods.plotCM(confusion_matrix(Ytest, (Yprobs>=bestROC).astype(int)),
                     normalize=False, ax=axes[1,1], xlabel=False)
plotMethods.plotCM(confusion_matrix(Ytest, (Yprobs>=bestROC).astype(int)), 
                     normalize=True, ax=axes[1,2], xlabel=False, ylabel=False)

_, bestPR = plotMethods.plotPR(Ytest, Yprobs, ax=axes[2,0])
plotMethods.plotCM(confusion_matrix(Ytest, (Yprobs>=bestPR).astype(int)), 
                     normalize=False, ax=axes[2,1], xlabel=False)
plotMethods.plotCM(confusion_matrix(Ytest, (Yprobs>=bestPR).astype(int)), 
                     normalize=True, ax=axes[2,2], xlabel=False, ylabel=False)

fig.tight_layout
# Out:
# invalid value encountered in true_divide
# <bound method Figure.tight_layout of <Figure size 1080x1440 with 9 Axes>>

# %%
plotMethods.metricsUplift(Ytest, Yprobs, thresholds=[0.5, bestROC, bestPR], 
                           columns=['original', 'best ROC', 'best PR'])
# Out:
#             original  best ROC  best PR
# AUC             0.58      0.63     0.52
# Precission      0.03      0.02     0.04
# Recall          0.28      0.54     0.07
# F1              0.05      0.04     0.05
# F2              0.10      0.10     0.06
# Log Loss        0.31      0.31     0.31

# %%
plotMethods.metricsUplift(Ytrain, xgbPipe.predict_proba(Xtrain)[:,1],
                           thresholds=[0.5, bestROC, bestPR], 
                           columns=['original', 'best ROC', 'best PR'])
# Out:
#             original  best ROC  best PR
# AUC             0.60      0.65     0.53
# Precission      0.03      0.02     0.04
# Recall          0.32      0.57     0.07
# F1              0.06      0.05     0.05
# F2              0.12      0.11     0.06
# Log Loss        0.31      0.31     0.31

# %% [markdown]
# All right, our model is performing very similarly on the training and dev sets. It has a really low precision and a bit better recall, but should perform sufficiently good for our uplift calculation here.
#
# With the trained model, building an S-Learner is rather straightforward. To calculate uplift, we are going to run the model twice, once with promotion = 1 and once again with promotion = 0. Then we will subtract the probability values to get the uplift score of each individual.

# %%
Xtest0 = Xtest.copy()
Xtest1 = Xtest.copy()
Xuplift = Xtest.copy()

Xtest0['promotion'] = 0
Xtest1['promotion'] = 1

xgbUp = xgbPipe.predict_proba(Xtest1)[:,1] - xgbPipe.predict_proba(Xtest0)[:,1]
Xuplift['xgb_uplift'] = xgbUp

# %%
fig, ax = plt.subplots(figsize=(12,7))
sns.set_context("notebook", font_scale=2, rc={"lines.linewidth": 2.5})
sns.distplot(xgbUp, kde_kws = {"color": "deepskyblue"}, hist_kws = {"color": "skyblue"}, ax=ax)
sns.despine()
plt.xlabel('Uplift score')
plt.ylabel('Number of observations')

plt.tight_layout()
# Out:
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# The distribution of uplift is mostly positive, which makes sense since we know from our A/B testing analysis that sending out promotions does increase the number of purchases on average. We can see quite a large peak around 0, indicating that a large proportion of people does not respond to our marketing at all. Importantly, we also see some observations with negative uplift scores, meaning that targeting some people actually discourages them from buying the product. Those are the people we definitely do not want to target.
#
# How much should we trust this plot though? How do we know how good this S-learner model is? Let's look at a comparison of the purchase rate between the targeted and not-targeted groups, in different ranges of the predicted uplift score. In the ranges with high uplift scores, we would expect to see larger differences between the two groups, while in those with lower uplift scores, we should have smaller differences.

# %%
upliftQuant, upliftQuant_bins = pd.qcut(x=Xuplift['xgb_uplift'], q=10, retbins=True, duplicates='drop')
Xuplift['xgb_quant'] = upliftQuant
Xuplift['Y'] = Ytest
QuantTarget = Xuplift.query('promotion == 1').groupby('xgb_quant')['Y'].mean()
QuantControl = Xuplift.query('promotion == 0').groupby('xgb_quant')['Y'].mean()
quantUp = QuantTarget - QuantControl

fig, ax = plt.subplots(figsize=(33,8))
quantUp.plot(kind="bar", stacked=True, color="skyblue", edgecolor='black')
plt.xticks(rotation=0)
plt.xlabel('Quantile bin')
plt.ylabel('True uplift')
# Out:
# Text(0, 0.5, 'True uplift')

# %% [markdown]
# The uplift quantile chart shows that, for the most part, true uplift increases from lower score bins to higher ones, which is what we would expect to see if the model is working. So it appears our model can, at least to some extent, segment out customers who more readily respond to the marketing campaign.
#
# What else can we learn from the quantile chart? From analysis of the A/B testing we know the IRR is about 1%. The quantile chart we created with the dev set tells us that by targeting the top decile of the uplift scores, **we could potentially achieve a treatment effect of around 1.5%**. The next few deciles appear to have larger treatment effects than our original IRR as well. It thus may make the most sense to **only target customers within the top 4 deciles** of uplift scores.
#
# We can also see that the *sleeping dog effect* has some support from observations of the true uplift. The bottom score deciles, consisting entirely of negative scores, have a negative true uplift. So it appears that targeting the bottom 20% of the population, by uplift score, would actually have a negative impact on the business.
#
# Let's also check the cumulative gain plot and calculate our AUUC metric, so that we can compare this model to the other ones.

# %%
gain = get_cumgain(Xuplift[['xgb_uplift', 'Y', 'promotion']], outcome_col='Y', treatment_col='promotion', normalize=True)
gain.columns = ['XGBoost S-learner', 'Random']
fig, ax = plt.subplots(figsize=(10,7))
sns.set_context("notebook", font_scale=2, rc={"lines.linewidth": 3.5})
sns.lineplot(data=gain, palette={'Random': 'darkgray', 'XGBoost S-learner': 'deepskyblue'}, dashes=False, ax=ax)
sns.despine()
plt.xlabel("Population")
plt.ylabel("Cumulative gain")
# Out:
# Text(0, 0.5, 'Cumulative gain')

# %%
AUUC = auuc_score(Xuplift[['xgb_uplift', 'Y', 'promotion']], outcome_col='Y', treatment_col='promotion', normalize=True)
print("Random AUUC: {:.3f}\nXGBoost S-learner {:.3f}".format(AUUC[1], AUUC[0]))
# Out:
# Random AUUC: 0.447
# XGBoost S-learner 0.938

# %% [markdown]
# Our uplift model performs much better than random targeting! Let's check what NIR and IIR we would generate if we targeted the first 3 deciles of our validation set. In order to check that we're going to discard people who were not targeted and did not buy the product from our validation set. This is due to the fact that we do not have ground truth scenario for how they would behave if we targeted them.

# %%
toDrop = Xuplift.query('promotion == 0 and Y == 0').index
NoPurchValid = Xuplift.drop(toDrop)
plotMethods.eda(NoPurchValid)
# Out:
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#                 type  count  missing  unique       mean       std  \
# V1             int64   4321        0       4   1.504050  0.866851
# V2           float64   4321        0    4321  30.016632  5.052259
# V3           float64   4321        0      40   0.013525  0.992774
# V4             int64   4321        0       2   1.669521  0.470440
# V5             int64   4321        0       4   2.312428  0.838349
# V6             int64   4321        0       4   2.503587  1.119709
# V7             int64   4321        0       2   1.697755  0.459284
# promotion      int64   4321        0       2   0.990974  0.094585
# xgb_uplift   float32   4321        0    3620   0.148971  0.145698
# xgb_quant   category   4321        0      10        NaN       NaN
# Y              int64   4321        0       2   0.024069  0.153280
#
#                            min             max    kurtosis       skew
# V1                           0               3   -0.668249  -0.005001
# V2                   10.389459       49.772803    0.026512   0.011639
# V3                    -1.68455        1.691984   -1.198498  -0.006148
# V4                           1               2   -1.480809  -0.721025
# V5                           1               4   -0.767420  -0.069009
# V6                           1               4   -1.363726  -0.003037
# V7                           1               2   -1.258324  -0.861544
# promotion                    0               1  105.927902 -10.386475
# xgb_uplift           -0.125205        0.501138   -1.129605   0.482425
# xgb_quant   (-0.126, -0.00956]  (0.368, 0.514]         NaN        NaN
# Y                            0               1   36.616484   6.212852

# %%
profit = plotMethods.incremental_profit_score(NoPurchValid['Y'], (NoPurchValid['xgb_uplift']>0.177).astype(int))
IRR = plotMethods.IRRscore(NoPurchValid['Y'], (NoPurchValid['xgb_uplift']>0.177).astype(int))
print("NIR: {:.2f}\nIRR {:.2f}%".format(profit, IRR*100))
# Out:
# NIR: 402.00
# IRR 2.39%

# %% [markdown]
# The original A/B testing, targeted at random around 50% of the sample group, generating IIR of 1%. This uplift model targets a smaller proportion of population, generating ~2.5 times higher IIR.

# %% [markdown]
# ### 2. Random Forest Classifier (bagging)

# %%
model = RandomForestClassifier()

rfPipe = make_pipeline(preproc, oversamp, model)
rfParams = {"randomforestclassifier__n_estimators": [800], 
            "randomforestclassifier__class_weight": [{0: 1.0, 1: 1.0}, {0: 1.0, 1: 2.0}, {0: 0.1, 1: 1.0}], 
            "randomforestclassifier__max_depth": range(5,11,1), "randomforestclassifier__min_samples_leaf": [20, 50, 70, 100, 200, 500]
           }

rfStudy = GridSearchCV(rfPipe, param_grid=rfParams, scoring= 'neg_log_loss', cv=5, verbose=10)

# %%
rfStudy.fit(Xhyper,Yhyper)

joblib.dump(rfStudy, './models/rf-slearn')  # save model
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-0.589, total=  13.1s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   13.1s remaining:    0.0s
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-0.584, total=  12.9s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   26.1s remaining:    0.0s
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-0.587, total=  12.9s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   39.0s remaining:    0.0s
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-0.585, total=  12.8s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   51.8s remaining:    0.0s
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-0.587, total=  13.0s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  1.1min remaining:    0.0s
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-0.588, total=  12.8s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  1.3min remaining:    0.0s
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-0.585, total=  12.8s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  1.5min remaining:    0.0s
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-0.588, total=  12.8s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  1.7min remaining:    0.0s
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-0.588, total=  12.8s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  1.9min remaining:    0.0s
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-0.588, total=  12.9s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-0.591, total=  12.8s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-0.590, total=  12.8s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-0.589, total=  12.8s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-0.593, total=  12.8s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-0.589, total=  12.9s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-0.594, total=  12.9s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-0.589, total=  13.0s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-0.588, total=  12.8s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-0.593, total=  13.0s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-0.590, total=  12.9s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-0.596, total=  13.0s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-0.593, total=  12.6s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-0.593, total=  12.5s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-0.593, total=  12.7s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-0.597, total=  12.8s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-0.610, total=  12.2s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-0.607, total=  12.3s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-0.608, total=  12.1s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-0.606, total=  12.4s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-0.611, total=  12.2s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-0.566, total=  14.4s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-0.562, total=  14.5s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-0.562, total=  14.5s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-0.568, total=  14.6s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-0.564, total=  14.5s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-0.567, total=  14.4s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-0.570, total=  14.5s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-0.566, total=  14.4s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-0.572, total=  14.5s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-0.568, total=  14.4s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-0.570, total=  14.3s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-0.566, total=  14.3s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-0.565, total=  14.2s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-0.569, total=  14.5s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-0.569, total=  14.2s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-0.572, total=  14.2s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-0.567, total=  14.5s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-0.569, total=  14.1s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-0.570, total=  14.4s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-0.572, total=  14.4s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-0.581, total=  14.2s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-0.577, total=  13.9s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-0.578, total=  14.2s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-0.583, total=  14.1s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-0.581, total=  14.0s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-0.602, total=  13.3s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-0.599, total=  13.2s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-0.601, total=  13.2s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-0.599, total=  13.4s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=6, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-0.604, total=  13.6s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-0.543, total=  16.0s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-0.540, total=  15.9s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-0.538, total=  15.9s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-0.542, total=  15.9s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-0.544, total=  16.0s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-0.546, total=  15.9s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-0.546, total=  15.9s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-0.549, total=  16.0s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-0.547, total=  15.7s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-0.545, total=  15.7s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-0.551, total=  15.6s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-0.550, total=  15.5s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-0.552, total=  15.5s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-0.553, total=  15.5s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-0.552, total=  15.5s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-0.556, total=  15.4s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-0.552, total=  15.4s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-0.554, total=  15.5s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-0.555, total=  15.4s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-0.555, total=  15.5s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-0.568, total=  15.0s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-0.565, total=  15.0s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-0.566, total=  15.2s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-0.568, total=  15.0s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-0.568, total=  15.2s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-0.597, total=  14.1s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-0.595, total=  13.7s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-0.596, total=  13.9s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-0.596, total=  13.7s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=7, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-0.600, total=  13.8s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-0.521, total=  17.2s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-0.520, total=  17.0s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-0.516, total=  17.0s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-0.522, total=  17.3s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-0.521, total=  17.3s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-0.527, total=  17.0s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-0.526, total=  17.0s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-0.530, total=  16.9s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-0.530, total=  16.9s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-0.530, total=  16.8s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-0.532, total=  16.7s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-0.533, total=  16.9s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-0.532, total=  16.6s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-0.530, total=  16.7s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-0.534, total=  17.2s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-0.541, total=  16.5s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-0.534, total=  16.8s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-0.538, total=  16.6s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-0.543, total=  16.6s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-0.541, total=  16.4s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-0.558, total=  15.8s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-0.557, total=  15.8s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-0.556, total=  15.8s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-0.559, total=  15.9s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-0.560, total=  15.9s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-0.594, total=  14.0s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-0.594, total=  14.0s
# [CV] randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 1.0, 1: 1.0}, randomforestclassifier__max_depth=8, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-0.596, total=  13.9s
# ...
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=9, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-1.784, total=  17.2s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=9, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=9, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-1.801, total=  17.0s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=9, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=9, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-1.786, total=  17.1s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=9, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=9, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-1.781, total=  16.8s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=9, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=9, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-1.794, total=  17.0s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=9, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=9, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-1.947, total=  14.9s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=9, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=9, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-1.950, total=  14.7s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=9, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=9, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-1.939, total=  14.7s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=9, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=9, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-1.936, total=  14.8s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=9, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=9, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-1.961, total=  14.6s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-1.449, total=  20.1s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-1.446, total=  20.0s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-1.445, total=  19.9s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-1.442, total=  20.0s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=20, randomforestclassifier__n_estimators=800, score=-1.428, total=  19.9s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-1.546, total=  19.2s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-1.552, total=  19.7s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-1.553, total=  19.5s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-1.544, total=  19.5s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=50, randomforestclassifier__n_estimators=800, score=-1.547, total=  19.0s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-1.587, total=  19.1s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-1.585, total=  18.9s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-1.586, total=  19.0s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-1.592, total=  19.0s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=70, randomforestclassifier__n_estimators=800, score=-1.593, total=  18.8s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-1.638, total=  18.4s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-1.644, total=  18.5s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-1.638, total=  18.6s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-1.645, total=  18.7s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=100, randomforestclassifier__n_estimators=800, score=-1.643, total=  18.4s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-1.765, total=  17.7s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-1.771, total=  17.7s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-1.766, total=  17.9s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-1.763, total=  17.4s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=200, randomforestclassifier__n_estimators=800, score=-1.770, total=  17.8s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-1.934, total=  15.2s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-1.945, total=  14.9s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-1.937, total=  14.9s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-1.937, total=  15.2s
# [CV] randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800
# [CV]  randomforestclassifier__class_weight={0: 0.1, 1: 1.0}, randomforestclassifier__max_depth=10, randomforestclassifier__min_samples_leaf=500, randomforestclassifier__n_estimators=800, score=-1.957, total=  14.6s
# [Parallel(n_jobs=1)]: Done 540 out of 540 | elapsed: 140.7min finished
# ['rf-slearn']

# %%
rfStudy = joblib.load('./models/rf-slearn')
rfStudy.best_params_
# Out:
# {'randomforestclassifier__class_weight': {0: 1.0, 1: 1.0},
#  'randomforestclassifier__max_depth': 10,
#  'randomforestclassifier__min_samples_leaf': 20,
#  'randomforestclassifier__n_estimators': 800}

# %%
rfPipe.set_params(**rfStudy.best_params_)
rfPipe.fit(Xtrain,Ytrain)
joblib.dump(rfPipe, './models/rf-slearn-trained')
Ypred = rfPipe.predict(Xtest)
Yprobs = rfPipe.predict_proba(Xtest)[:,1]
cm = confusion_matrix(Ytest, Ypred)

# %%
fig, axes = plt.subplots(3,3, figsize=(15,20), gridspec_kw={'hspace': 0.3})
axes[0,0].set_visible(False)
plotMethods.plotCM(cm, normalize=False, ax=axes[0,1], xlabel=False)
plotMethods.plotCM(cm, normalize=True, ax=axes[0,2], xlabel=False, ylabel=False)

_, bestROC = plotMethods.plotROC(Ytest, Yprobs, ax=axes[1,0])
plotMethods.plotCM(confusion_matrix(Ytest, (Yprobs>=bestROC).astype(int)),
                     normalize=False, ax=axes[1,1], xlabel=False)
plotMethods.plotCM(confusion_matrix(Ytest, (Yprobs>=bestROC).astype(int)), 
                     normalize=True, ax=axes[1,2], xlabel=False, ylabel=False)

_, bestPR = plotMethods.plotPR(Ytest, Yprobs, ax=axes[2,0])
plotMethods.plotCM(confusion_matrix(Ytest, (Yprobs>=bestPR).astype(int)), 
                     normalize=False, ax=axes[2,1], xlabel=False)
plotMethods.plotCM(confusion_matrix(Ytest, (Yprobs>=bestPR).astype(int)), 
                     normalize=True, ax=axes[2,2], xlabel=False, ylabel=False)

fig.tight_layout
# Out:
# <bound method Figure.tight_layout of <Figure size 1080x1440 with 9 Axes>>

# %%
plotMethods.metricsUplift(Ytest, Yprobs, thresholds=[0.5, bestROC, bestPR], 
                           columns=['original', 'best ROC', 'best PR',])
# Out:
#             original  best ROC  best PR
# AUC             0.60      0.62     0.58
# Precission      0.03      0.02     0.03
# Recall          0.38      0.62     0.29
# F1              0.05      0.04     0.05
# F2              0.10      0.09     0.10
# Log Loss        0.46      0.46     0.46

# %%
plotMethods.metricsUplift(Ytrain, rfPipe.predict_proba(Xtrain)[:,1],
                           thresholds=[0.5, bestROC, bestPR], 
                           columns=['original', 'best ROC', 'best PR'])
# Out:
#             original  best ROC  best PR
# AUC             0.66      0.69     0.61
# Precission      0.03      0.02     0.03
# Recall          0.50      0.78     0.34
# F1              0.06      0.05     0.06
# F2              0.13      0.11     0.12
# Log Loss        0.45      0.45     0.45

# %% [markdown]
# This model also performs simlarly on the training and dev datasets, indicating we are not overfitting. But the logloss score is quite a bit worse than for the XGBoost model.
#
# Let's calculate the uplift now.

# %%
rfUp = rfPipe.predict_proba(Xtest1)[:,1] - rfPipe.predict_proba(Xtest0)[:,1]
Xuplift['rf_uplift'] = rfUp

# %%
fig, ax = plt.subplots(figsize=(12,7))
sns.set_context("notebook", font_scale=2, rc={"lines.linewidth": 2.5})
sns.distplot(rfUp, kde_kws = {"color": "deepskyblue"}, hist_kws = {"color": "skyblue"}, ax=ax)
sns.despine()
plt.xlabel('Uplift score')
plt.ylabel('Number of observations')

plt.tight_layout()
# Out:
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# Again, the distribution of uplift is mostly positive, which is expected. We can see quite a large peak around 0, indicating that a large proportion of people does not respond to our marketing at all, and a second peak around 0.3.
#
# Let's look at a our quantile and cumulative gain plots to try and evaluate this model.

# %%
upliftQuant, upliftQuant_bins = pd.qcut(x=Xuplift['rf_uplift'], q=10, retbins=True, duplicates='drop')
Xuplift['rf_quant'] = upliftQuant
Xuplift['Y'] = Ytest
QuantTarget = Xuplift.query('promotion == 1').groupby('rf_quant')['Y'].mean()
QuantControl = Xuplift.query('promotion == 0').groupby('rf_quant')['Y'].mean()
quantUp = QuantTarget - QuantControl

fig, ax = plt.subplots(figsize=(35,8))
quantUp.plot(kind="bar", stacked=True, color="skyblue", edgecolor='black')
plt.xticks(rotation=0)
plt.xlabel('Quantile bin')
plt.ylabel('True uplift')
# Out:
# Text(0, 0.5, 'True uplift')

# %% [markdown]
# Here, the first quantile is providing a lower uplift than in the case of the XGBoost S-learner. It also seems like the 3rd quantile is characterized by much bigger uplift than e.g. the second quantile. Should we target the first 3 quantiles?
#
# Let's also check the cumulative gain plot and calculate our AUUC metric, so that we can compare this model to the other ones.

# %%
gain = get_cumgain(Xuplift[['xgb_uplift','rf_uplift', 'Y', 'promotion']], outcome_col='Y', treatment_col='promotion', normalize=True)
gain.columns = ['XGB S-learner', 'RF S-learner', 'Random']
fig, ax = plt.subplots(figsize=(10,7))
sns.set_context("notebook", font_scale=2, rc={"lines.linewidth": 3.5})
sns.lineplot(data=gain, palette={'Random': 'darkgray', 'XGB S-learner': 'deepskyblue', 'RF S-learner': 'darkorange'}, dashes=False, ax=ax)
sns.despine()
plt.xlabel("Population")
plt.ylabel("Cumulative gain")
# Out:
# Text(0, 0.5, 'Cumulative gain')

# %%
AUUC = auuc_score(Xuplift[['xgb_uplift','rf_uplift', 'Y', 'promotion']], outcome_col='Y', treatment_col='promotion', normalize=True)
print("Random AUUC: {:.3f}\nXGB S-learner {:.3f}\nRF S-learner {:.3f}".format(AUUC[2], AUUC[0], AUUC[1]))
# Out:
# Random AUUC: 0.447
# XGB S-learner 0.941
# RF S-learner 0.967

# %% [markdown]
# Our uplift model performs  better than random targeting, and slightly better than the XGBoost-based S-learner.

# %%
toDrop = Xuplift.query('promotion == 0 and Y == 0').index
NoPurchValid = Xuplift.drop(toDrop)
plotMethods.eda(NoPurchValid)
# Out:
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#                 type  count  missing  unique       mean       std  \
# V1             int64   4321        0       4   1.504050  0.866851
# V2           float64   4321        0    4321  30.016632  5.052259
# V3           float64   4321        0      40   0.013525  0.992774
# V4             int64   4321        0       2   1.669521  0.470440
# V5             int64   4321        0       4   2.312428  0.838349
# V6             int64   4321        0       4   2.503587  1.119709
# V7             int64   4321        0       2   1.697755  0.459284
# promotion      int64   4321        0       2   0.990974  0.094585
# xgb_uplift   float32   4321        0    3620   0.148971  0.145698
# xgb_quant   category   4321        0      10        NaN       NaN
# Y              int64   4321        0       2   0.024069  0.153280
# rf_uplift    float64   4321        0    4315   0.155628  0.166268
# rf_quant    category   4321        0      10        NaN       NaN
#
#                            min             max    kurtosis       skew
# V1                           0               3   -0.668249  -0.005001
# V2                   10.389459       49.772803    0.026512   0.011639
# V3                    -1.68455        1.691984   -1.198498  -0.006148
# V4                           1               2   -1.480809  -0.721025
# V5                           1               4   -0.767420  -0.069009
# V6                           1               4   -1.363726  -0.003037
# V7                           1               2   -1.258324  -0.861544
# promotion                    0               1  105.927902 -10.386475
# xgb_uplift           -0.125205        0.501138   -1.129605   0.482425
# xgb_quant   (-0.126, -0.00956]  (0.368, 0.514]         NaN        NaN
# Y                            0               1   36.616484   6.212852
# rf_uplift            -0.244097        0.607996   -1.026063   0.273104
# rf_quant     (-0.245, -0.0438]  (0.397, 0.608]         NaN        NaN

# %%
profit = plotMethods.incremental_profit_score(NoPurchValid['Y'], (NoPurchValid['rf_uplift']>0.271).astype(int))
IRR = plotMethods.IRRscore(NoPurchValid['Y'], (NoPurchValid['rf_uplift']>0.271).astype(int))
print("NIR: {:.2f}\nIRR {:.2f}%".format(profit, IRR*100))
# Out:
# NIR: 306.00
# IRR 2.08%

# %% [markdown]
# Although the RF-based S-learner is associated with higher AUUC metric, it gives us a slightly lower NIR and IIR than the XGBoost-based S-learner. Before we get to making any predictions on the the test dataset though, let's see how the remaining uplift modeling approaches are doing:
#
#
# 1. [Traditional predictive model](./1.Classical-predictive-models.ipynb)
# 2. [T-learner model (two-models "uplift classifier")](./3.T-learner.ipynb)
# 3. [Direct uplift modeling](./4.Direct-uplift.ipynb)
